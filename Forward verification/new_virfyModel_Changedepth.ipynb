# %%
from SimPEG import  maps, utils
import SimPEG.electromagnetics.time_domain as tdem
from discretize import TreeMesh, TensorMesh
from discretize.utils import mkvc, refine_tree_xyz, active_from_xyz
import empymod
import numpy as np
from scipy.constants import mu_0
from scipy.interpolate import griddata
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.colors import LogNorm
from matplotlib import animation, collections

try:
    from pymatsolver import Pardiso as Solver
except:
    from SimPEG import SolverLU as Solver

import sys
# sys.path.append("..")  # 添加上一级目录到sys.path
# from utils import  simulation # 导入module模块
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

plt.style.use('bmh')
# Out:
# /tmp/ipykernel_24409/2301404441.py:1: FutureWarning: Importing `SimPEG` is deprecated. please import from `simpeg`.
#   from SimPEG import  maps, utils

# %%
dh = 10.0
hx = [(dh, 20, -1.3),(dh, 15), (1, 10), (dh, 5),(dh, 20, 1.3)]
hy = [(dh, 20, -1.3), (dh, 1), (dh, 20, 1.3)]
# hz = [(dh, 5, -1.3), (dh, 20), (dh, 5, 1.3)]
hz = [(dh, 20, -1.3),  (1, 15), (0.01, 100), (1, 10), (dh, 3), (1, 15), (dh, 6), (dh, 20, 1.3)]
mesh = TensorMesh([hx, hy, hz], "CCC")

halfspace_value = 100.0

# Find cells below topography and define mapping
air_value = 1e8
ind_active = mesh.gridCC[:, 2] < 0.0
model_map = maps.InjectActiveCells(mesh, ind_active, air_value)

# Define the model
model = halfspace_value * np.ones(ind_active.sum())

# We can plot a slice of the model at Y=-2.5
fig = plt.figure(figsize=(5, 5))
ax = fig.add_subplot(111)
ind_slice = int(mesh.shape_cells[1] / 2)
mesh.plot_slice(model_map * model, normal="Y", ax=ax, ind=ind_slice, grid=True)
ax.set_title("Model slice at y = {} m".format(mesh.cell_centers_y[ind_slice]))
ax.set_xlim([-100, 100])
ax.set_ylim([-100, 100])
ax.set_title("")
ax.grid(False)
plt.show()

# %%
mesh
# Out:
#   TensorMesh: 542,430 cells
#
#                       MESH EXTENT             CELL WIDTH      FACTOR
#   dir    nC        min           max         min       max      max
#   ---   ---  ---------------------------  ------------------  ------
#    x     70     -8,297.15      8,297.15      1.00  1,900.50   10.00
#    y     41     -8,197.15      8,197.15     10.00  1,900.50    1.30
#    z    189     -8,257.65      8,257.65      0.01  1,900.50  100.00

# %%
def get_mesh():
    dh = 10.0
    hx = [(dh, 20, -1.3),(dh, 15), (1, 10), (dh, 5),(dh, 20, 1.3)]
    hy = [(dh, 20, -1.3), (dh, 1), (dh, 20, 1.3)]
    # hz = [(dh, 5, -1.3), (dh, 20), (dh, 5, 1.3)]
    # hz = [(dh, 20, -1.3),  (1, 15), (0.1, 10), (1, 15),(dh, 10), (dh, 20, 1.3)]
    hz = [(dh, 20, -1.3),  (1, 15), (0.01, 10), (0.01, 2), (1, 10), (dh, 3), (1, 15), (dh, 6), (dh, 20, 1.3)]
    # hz = [(dh, 20, -1.3),  (1, 10), (0.1, 10), (1, 10), (dh, 3), (1, 10), (dh, 6), (dh, 20, 1.3)]
    mesh = TensorMesh([hx, hy, hz], "CCC")
    return mesh

def set_layer_model(mesh):
    sigma_air = 1e-8
    sigma_layer1 = 1/10
    sigma_layer2 = 1/100
    sigma_layer3 = 1e6
    sigma_layer4 = 1/100
    sigma_layer5 = 1/300

    model = np.ones(mesh.nC) * sigma_air
    layer1 = ((mesh.gridCC[:,2] > -10) & (mesh.gridCC[:,2] <= 0))
    layer2 = ((mesh.gridCC[:,2] > -50) & (mesh.gridCC[:,2] <= -10))
    layer3 = ((mesh.gridCC[:,2] > -50.05) & (mesh.gridCC[:,2] <= -50))
    layer4 = ((mesh.gridCC[:,2] > -90) & (mesh.gridCC[:,2] <= -50.05))
    layer5 = ((mesh.gridCC[:,2] <= -90))

    model[layer1] = sigma_layer1
    model[layer2] = sigma_layer2
    model[layer3] = sigma_layer3
    model[layer4] = sigma_layer4
    model[layer5] = sigma_layer5
    return model

def plot_model(mesh, model, title=None):
    fig, ax = plt.subplots(figsize=(6, 6))
    ind_slice = int(mesh.shape_cells[1] / 2)
    mesh.plot_slice(np.log10(model), normal="Y", ax=ax, ind=ind_slice, grid=False)
    ax.set_xlim([-30, 30])
    ax.set_ylim([-150.1, 0])
    ax.set_xlabel("X / m")
    ax.set_ylabel("Z / m")
    ax.tick_params(axis='both', which='major', labelsize=14)
    ax.set_title("")
    ax.grid(False)
    plt.savefig("./Model_no_Grid.png", dpi = 350, bbox_inches='tight')

# %%
mesh = get_mesh()
model = set_layer_model(mesh)
plot_model(mesh, model, title="Layered Model")

# %%
mesh
# Out:
#   TensorMesh: 289,870 cells
#
#                       MESH EXTENT             CELL WIDTH      FACTOR
#   dir    nC        min           max         min       max      max
#   ---   ---  ---------------------------  ------------------  ------
#    x     70     -8,297.15      8,297.15      1.00  1,900.50   10.00
#    y     41     -8,197.15      8,197.15     10.00  1,900.50    1.30
#    z    101     -8,257.21      8,257.21      0.01  1,900.50  100.00

# %%
def forward(mesh, model, source_locations, receiver_locations, path):
    times = np.logspace(np.log10(1e-6), np.log10(1e-2), 300)

    # src_list = []
    rec_list = []
    # Set up the receiver list
    # for i in ["x"]:
    #     rec_list.append(tdem.Rx.PointElectricField(
    #             orientation=i,
    #             times=self.times,
    #             locations=self.receiver_locations,
    #         ))
    for i in ["x", "y", "z"]:
        rec_list.append(tdem.Rx.PointElectricField(
                orientation=i,
                times=times,
                locations=receiver_locations,
            ))
    # for i in ["x", "y", "z"]:
    #     rec_list.append(tdem.Rx.PointMagneticFluxTimeDerivative(
    #                 orientation = i,
    #                 times=times,
    #                 locations=receiver_locations)
    #                 )
    # Set up the source list
    src_list = [
        tdem.Src.LineCurrent(
            receiver_list=rec_list,
            location=np.array(source_locations),
        ),
    ]


    # Create `Survey`
    survey = tdem.Survey(src_list)

    # time_steps = [1e-1, (1e-2, 21), (3e-2, 23), (1e-1, 21), (3e-1, 23)]
    time_steps =  [1e-7, (1e-7,81), (3e-7,81), (1e-6,81), (3e-6,81), (1e-5, 81), (3e-5, 81),(1e-4, 81), (3e-4, 81),(1e-3, 81),(3e-3, 61)]
    # time_steps =  [1e-7, (1e-7,21), (3e-7,21), (1e-6,21), (3e-6,21), (1e-5, 21), (3e-5, 21),(1e-4, 21), (3e-4, 21),(1e-3, 21)]
    # Define the `Simulation`
    prob = tdem.Simulation3DElectricField(
        mesh,
        survey=survey,
        sigmaMap=maps.IdentityMap(mesh),
        solver=Solver,
        time_steps=time_steps,
        verbose = True
    )

    # Run the forward simulation
    # prob.mu = self.mur*mu_0
    dpred = prob.dpred(model)
    np.save(path, dpred)

# %%
mesh
# Out:
#   TensorMesh: 289,870 cells
#
#                       MESH EXTENT             CELL WIDTH      FACTOR
#   dir    nC        min           max         min       max      max
#   ---   ---  ---------------------------  ------------------  ------
#    x     70     -8,297.15      8,297.15      1.00  1,900.50   10.00
#    y     41     -8,197.15      8,197.15     10.00  1,900.50    1.30
#    z    101     -8,257.21      8,257.21      0.01  1,900.50  100.00

# %%
receiver_locations = np.array([[50, 0, -1.5]])
source_locations = np.array([[-60, 0, -1.5], [-50, 0, -1.5]])

path = "./data2/3D_solution_changdepth.npy"
mesh = get_mesh()
model = set_layer_model(mesh)
forward(mesh, model, source_locations, receiver_locations, path)
# Out:
# Calculating Initial fields
# Factoring the system matrix for the DC problem
# **************************************************
# Calculating fields(m)
# **************************************************
# Factoring...   (dt = 1.000000e-07)
# Done
#     Solving...   (tInd = 1)
#     Done...
#     Solving...   (tInd = 2)
#     Done...
#     Solving...   (tInd = 3)
#     Done...
#     Solving...   (tInd = 4)
#     Done...
#     Solving...   (tInd = 5)
#     Done...
#     Solving...   (tInd = 6)
#     Done...
#     Solving...   (tInd = 7)
#     Done...
#     Solving...   (tInd = 8)
#     Done...
#     Solving...   (tInd = 9)
#     Done...
#     Solving...   (tInd = 10)
#     Done...
#     Solving...   (tInd = 11)
#     Done...
#     Solving...   (tInd = 12)
#     Done...
#     Solving...   (tInd = 13)
#     Done...
#     Solving...   (tInd = 14)
#     Done...
#     Solving...   (tInd = 15)
#     Done...
#     Solving...   (tInd = 16)
#     Done...
#     Solving...   (tInd = 17)
#     Done...
#     Solving...   (tInd = 18)
#     Done...
#     Solving...   (tInd = 19)
#     Done...
#     Solving...   (tInd = 20)
#     Done...
#     Solving...   (tInd = 21)
#     Done...
#     Solving...   (tInd = 22)
#     Done...
#     Solving...   (tInd = 23)
#     Done...
#     Solving...   (tInd = 24)
#     Done...
#     Solving...   (tInd = 25)
#     Done...
#     Solving...   (tInd = 26)
#     Done...
#     Solving...   (tInd = 27)
#     Done...
#     Solving...   (tInd = 28)
#     Done...
#     Solving...   (tInd = 29)
#     Done...
#     Solving...   (tInd = 30)
#     Done...
#     Solving...   (tInd = 31)
#     Done...
#     Solving...   (tInd = 32)
#     Done...
#     Solving...   (tInd = 33)
#     Done...
#     Solving...   (tInd = 34)
#     Done...
#     Solving...   (tInd = 35)
#     Done...
#     Solving...   (tInd = 36)
#     Done...
#     Solving...   (tInd = 37)
#     Done...
#     Solving...   (tInd = 38)
#     Done...
#     Solving...   (tInd = 39)
#     Done...
#     Solving...   (tInd = 40)
#     Done...
#     Solving...   (tInd = 41)
#     Done...
#     Solving...   (tInd = 42)
#     Done...
#     Solving...   (tInd = 43)
#     Done...
#     Solving...   (tInd = 44)
#     Done...
#     Solving...   (tInd = 45)
#     Done...
#     Solving...   (tInd = 46)
#     Done...
#     Solving...   (tInd = 47)
#     Done...
#     Solving...   (tInd = 48)
#     Done...
#     Solving...   (tInd = 49)
#     Done...
#     Solving...   (tInd = 50)
#     Done...
#     Solving...   (tInd = 51)
#     Done...
#     Solving...   (tInd = 52)
#     Done...
#     Solving...   (tInd = 53)
#     Done...
#     Solving...   (tInd = 54)
#     Done...
#     Solving...   (tInd = 55)
#     Done...
#     Solving...   (tInd = 56)
#     Done...
#     Solving...   (tInd = 57)
#     Done...
#     Solving...   (tInd = 58)
#     Done...
#     Solving...   (tInd = 59)
#     Done...
#     Solving...   (tInd = 60)
#     Done...
#     Solving...   (tInd = 61)
#     Done...
#     Solving...   (tInd = 62)
#     Done...
#     Solving...   (tInd = 63)
#     Done...
#     Solving...   (tInd = 64)
#     Done...
#     Solving...   (tInd = 65)
#     Done...
#     Solving...   (tInd = 66)
#     Done...
#     Solving...   (tInd = 67)
#     Done...
#     Solving...   (tInd = 68)
#     Done...
#     Solving...   (tInd = 69)
#     Done...
#     Solving...   (tInd = 70)
#     Done...
#     Solving...   (tInd = 71)
#     Done...
#     Solving...   (tInd = 72)
#     Done...
#     Solving...   (tInd = 73)
#     Done...
#     Solving...   (tInd = 74)
#     Done...
#     Solving...   (tInd = 75)
#     Done...
#     Solving...   (tInd = 76)
#     Done...
#     Solving...   (tInd = 77)
#     Done...
#     Solving...   (tInd = 78)
#     Done...
#     Solving...   (tInd = 79)
#     Done...
#     Solving...   (tInd = 80)
#     Done...
#     Solving...   (tInd = 81)
#     Done...
#     Solving...   (tInd = 82)
#     Done...
# Factoring...   (dt = 3.000000e-07)
# Done
#     Solving...   (tInd = 83)
#     Done...
#     Solving...   (tInd = 84)
#     Done...
#     Solving...   (tInd = 85)
#     Done...
#     Solving...   (tInd = 86)
#     Done...
#     Solving...   (tInd = 87)
#     Done...
#     Solving...   (tInd = 88)
#     Done...
#     Solving...   (tInd = 89)
#     Done...
#     Solving...   (tInd = 90)
#     Done...
#     Solving...   (tInd = 91)
#     Done...
#     Solving...   (tInd = 92)
#     Done...
#     Solving...   (tInd = 93)
#     Done...
#     Solving...   (tInd = 94)
#     Done...
#     Solving...   (tInd = 95)
#     Done...
#     Solving...   (tInd = 96)
#     Done...
#     Solving...   (tInd = 97)
#     Done...
#     Solving...   (tInd = 98)
#     Done...
#     Solving...   (tInd = 99)
#     Done...
#     Solving...   (tInd = 100)
#     Done...
#     Solving...   (tInd = 101)
#     Done...
#     Solving...   (tInd = 102)
#     Done...
#     Solving...   (tInd = 103)
#     Done...
#     Solving...   (tInd = 104)
#     Done...
#     Solving...   (tInd = 105)
#     Done...
#     Solving...   (tInd = 106)
#     Done...
#     Solving...   (tInd = 107)
#     Done...
#     Solving...   (tInd = 108)
#     Done...
#     Solving...   (tInd = 109)
#     Done...
#     Solving...   (tInd = 110)
#     Done...
#     Solving...   (tInd = 111)
#     Done...
#     Solving...   (tInd = 112)
#     Done...
#     Solving...   (tInd = 113)
#     Done...
#     Solving...   (tInd = 114)
#     Done...
#     Solving...   (tInd = 115)
#     Done...
#     Solving...   (tInd = 116)
#     Done...
#     Solving...   (tInd = 117)
#     Done...
#     Solving...   (tInd = 118)
#     Done...
#     Solving...   (tInd = 119)
#     Done...
#     Solving...   (tInd = 120)
#     Done...
#     Solving...   (tInd = 121)
#     Done...
#     Solving...   (tInd = 122)
#     Done...
#     Solving...   (tInd = 123)
#     Done...
#     Solving...   (tInd = 124)
#     Done...
#     Solving...   (tInd = 125)
#     Done...
#     Solving...   (tInd = 126)
#     Done...
#     Solving...   (tInd = 127)
#     Done...
#     Solving...   (tInd = 128)
#     Done...
#     Solving...   (tInd = 129)
#     Done...
#     Solving...   (tInd = 130)
#     Done...
#     Solving...   (tInd = 131)
#     Done...
#     Solving...   (tInd = 132)
#     Done...
#     Solving...   (tInd = 133)
#     Done...
#     Solving...   (tInd = 134)
#     Done...
#     Solving...   (tInd = 135)
#     Done...
#     Solving...   (tInd = 136)
#     Done...
#     Solving...   (tInd = 137)
#     Done...
#     Solving...   (tInd = 138)
#     Done...
#     Solving...   (tInd = 139)
#     Done...
#     Solving...   (tInd = 140)
#     Done...
#     Solving...   (tInd = 141)
#     Done...
#     Solving...   (tInd = 142)
#     Done...
#     Solving...   (tInd = 143)
#     Done...
#     Solving...   (tInd = 144)
#     Done...
#     Solving...   (tInd = 145)
#     Done...
#     Solving...   (tInd = 146)
#     Done...
#     Solving...   (tInd = 147)
#     Done...
#     Solving...   (tInd = 148)
#     Done...
#     Solving...   (tInd = 149)
#     Done...
#     Solving...   (tInd = 150)
#     Done...
#     Solving...   (tInd = 151)
#     Done...
#     Solving...   (tInd = 152)
#     Done...
#     Solving...   (tInd = 153)
#     Done...
#     Solving...   (tInd = 154)
#     Done...
#     Solving...   (tInd = 155)
#     Done...
#     Solving...   (tInd = 156)
#     Done...
#     Solving...   (tInd = 157)
#     Done...
#     Solving...   (tInd = 158)
#     Done...
#     Solving...   (tInd = 159)
#     Done...
#     Solving...   (tInd = 160)
#     Done...
#     Solving...   (tInd = 161)
#     Done...
#     Solving...   (tInd = 162)
#     Done...
#     Solving...   (tInd = 163)
#     Done...
# Factoring...   (dt = 1.000000e-06)
# Done
#     Solving...   (tInd = 164)
#     Done...
#     Solving...   (tInd = 165)
#     Done...
#     Solving...   (tInd = 166)
#     Done...
#     Solving...   (tInd = 167)
#     Done...
#     Solving...   (tInd = 168)
#     Done...
#     Solving...   (tInd = 169)
#     Done...
#     Solving...   (tInd = 170)
#     Done...
#     Solving...   (tInd = 171)
#     Done...
#     Solving...   (tInd = 172)
#     Done...
#     Solving...   (tInd = 173)
#     Done...
#     Solving...   (tInd = 174)
#     Done...
#     Solving...   (tInd = 175)
#     Done...
#     Solving...   (tInd = 176)
#     Done...
#     Solving...   (tInd = 177)
#     Done...
#     Solving...   (tInd = 178)
#     Done...
#     Solving...   (tInd = 179)
#     Done...
#     Solving...   (tInd = 180)
#     Done...
#     Solving...   (tInd = 181)
#     Done...
#     Solving...   (tInd = 182)
#     Done...
#     Solving...   (tInd = 183)
#     Done...
#     Solving...   (tInd = 184)
#     Done...
#     Solving...   (tInd = 185)
#     Done...
#     Solving...   (tInd = 186)
#     Done...
#     Solving...   (tInd = 187)
#     Done...
#     Solving...   (tInd = 188)
#     Done...
#     Solving...   (tInd = 189)
#     Done...
#     Solving...   (tInd = 190)
#     Done...
#     Solving...   (tInd = 191)
#     Done...
#     Solving...   (tInd = 192)
#     Done...
#     Solving...   (tInd = 193)
#     Done...
#     Solving...   (tInd = 194)
#     Done...
#     Solving...   (tInd = 195)
#     Done...
#     Solving...   (tInd = 196)
#     Done...
#     Solving...   (tInd = 197)
#     Done...
#     Solving...   (tInd = 198)
#     Done...
#     Solving...   (tInd = 199)
#     Done...
#     Solving...   (tInd = 200)
#     Done...
#     Solving...   (tInd = 201)
#     Done...
#     Solving...   (tInd = 202)
#     Done...
#     Solving...   (tInd = 203)
#     Done...
#     Solving...   (tInd = 204)
#     Done...
#     Solving...   (tInd = 205)
#     Done...
#     Solving...   (tInd = 206)
#     Done...
#     Solving...   (tInd = 207)
#     Done...
#     Solving...   (tInd = 208)
#     Done...
#     Solving...   (tInd = 209)
#     Done...
#     Solving...   (tInd = 210)
#     Done...
#     Solving...   (tInd = 211)
#     Done...
#     Solving...   (tInd = 212)
#     Done...
#     Solving...   (tInd = 213)
#     Done...
#     Solving...   (tInd = 214)
#     Done...
#     Solving...   (tInd = 215)
#     Done...
#     Solving...   (tInd = 216)
#     Done...
#     Solving...   (tInd = 217)
#     Done...
#     Solving...   (tInd = 218)
#     Done...
#     Solving...   (tInd = 219)
#     Done...
#     Solving...   (tInd = 220)
#     Done...
#     Solving...   (tInd = 221)
#     Done...
#     Solving...   (tInd = 222)
#     Done...
#     Solving...   (tInd = 223)
#     Done...
#     Solving...   (tInd = 224)
#     Done...
#     Solving...   (tInd = 225)
#     Done...
#     Solving...   (tInd = 226)
#     Done...
#     Solving...   (tInd = 227)
#     Done...
#     Solving...   (tInd = 228)
#     Done...
#     Solving...   (tInd = 229)
#     Done...
#     Solving...   (tInd = 230)
#     Done...
#     Solving...   (tInd = 231)
#     Done...
#     Solving...   (tInd = 232)
#     Done...
#     Solving...   (tInd = 233)
#     Done...
#     Solving...   (tInd = 234)
#     Done...
#     Solving...   (tInd = 235)
#     Done...
#     Solving...   (tInd = 236)
#     Done...
#     Solving...   (tInd = 237)
#     Done...
#     Solving...   (tInd = 238)
#     Done...
#     Solving...   (tInd = 239)
#     Done...
#     Solving...   (tInd = 240)
#     Done...
#     Solving...   (tInd = 241)
#     Done...
#     Solving...   (tInd = 242)
#     Done...
#     Solving...   (tInd = 243)
#     Done...
#     Solving...   (tInd = 244)
#     Done...
# Factoring...   (dt = 3.000000e-06)
# Done
#     Solving...   (tInd = 245)
#     Done...
#     Solving...   (tInd = 246)
#     Done...
#     Solving...   (tInd = 247)
#     Done...
#     Solving...   (tInd = 248)
#     Done...
#     Solving...   (tInd = 249)
#     Done...
#     Solving...   (tInd = 250)
#     Done...
#     Solving...   (tInd = 251)
#     Done...
#     Solving...   (tInd = 252)
#     Done...
#     Solving...   (tInd = 253)
#     Done...
#     Solving...   (tInd = 254)
#     Done...
#     Solving...   (tInd = 255)
#     Done...
#     Solving...   (tInd = 256)
#     Done...
#     Solving...   (tInd = 257)
#     Done...
#     Solving...   (tInd = 258)
#     Done...
#     Solving...   (tInd = 259)
#     Done...
#     Solving...   (tInd = 260)
#     Done...
#     Solving...   (tInd = 261)
#     Done...
#     Solving...   (tInd = 262)
#     Done...
#     Solving...   (tInd = 263)
#     Done...
#     Solving...   (tInd = 264)
#     Done...
#     Solving...   (tInd = 265)
#     Done...
#     Solving...   (tInd = 266)
#     Done...
#     Solving...   (tInd = 267)
#     Done...
#     Solving...   (tInd = 268)
#     Done...
#     Solving...   (tInd = 269)
#     Done...
#     Solving...   (tInd = 270)
#     Done...
#     Solving...   (tInd = 271)
#     Done...
#     Solving...   (tInd = 272)
#     Done...
#     Solving...   (tInd = 273)
#     Done...
#     Solving...   (tInd = 274)
#     Done...
#     Solving...   (tInd = 275)
#     Done...
#     Solving...   (tInd = 276)
#     Done...
#     Solving...   (tInd = 277)
#     Done...
#     Solving...   (tInd = 278)
#     Done...
#     Solving...   (tInd = 279)
#     Done...
#     Solving...   (tInd = 280)
#     Done...
#     Solving...   (tInd = 281)
#     Done...
#     Solving...   (tInd = 282)
#     Done...
#     Solving...   (tInd = 283)
#     Done...
#     Solving...   (tInd = 284)
#     Done...
#     Solving...   (tInd = 285)
#     Done...
#     Solving...   (tInd = 286)
#     Done...
#     Solving...   (tInd = 287)
#     Done...
#     Solving...   (tInd = 288)
#     Done...
#     Solving...   (tInd = 289)
#     Done...
#     Solving...   (tInd = 290)
#     Done...
#     Solving...   (tInd = 291)
#     Done...
#     Solving...   (tInd = 292)
#     Done...
#     Solving...   (tInd = 293)
#     Done...
#     Solving...   (tInd = 294)
#     Done...
#     Solving...   (tInd = 295)
#     Done...
#     Solving...   (tInd = 296)
#     Done...
#     Solving...   (tInd = 297)
#     Done...
#     Solving...   (tInd = 298)
#     Done...
#     Solving...   (tInd = 299)
#     Done...
#     Solving...   (tInd = 300)
#     Done...
#     Solving...   (tInd = 301)
#     Done...
#     Solving...   (tInd = 302)
#     Done...
#     Solving...   (tInd = 303)
#     Done...
#     Solving...   (tInd = 304)
#     Done...
#     Solving...   (tInd = 305)
#     Done...
#     Solving...   (tInd = 306)
#     Done...
#     Solving...   (tInd = 307)
#     Done...
#     Solving...   (tInd = 308)
#     Done...
#     Solving...   (tInd = 309)
#     Done...
#     Solving...   (tInd = 310)
#     Done...
#     Solving...   (tInd = 311)
#     Done...
#     Solving...   (tInd = 312)
#     Done...
#     Solving...   (tInd = 313)
#     Done...
#     Solving...   (tInd = 314)
#     Done...
#     Solving...   (tInd = 315)
#     Done...
#     Solving...   (tInd = 316)
#     Done...
#     Solving...   (tInd = 317)
#     Done...
#     Solving...   (tInd = 318)
#     Done...
#     Solving...   (tInd = 319)
#     Done...
#     Solving...   (tInd = 320)
#     Done...
#     Solving...   (tInd = 321)
#     Done...
#     Solving...   (tInd = 322)
#     Done...
#     Solving...   (tInd = 323)
#     Done...
#     Solving...   (tInd = 324)
#     Done...
#     Solving...   (tInd = 325)
#     Done...
# Factoring...   (dt = 1.000000e-05)
# Done
#     Solving...   (tInd = 326)
#     Done...
#     Solving...   (tInd = 327)
#     Done...
#     Solving...   (tInd = 328)
#     Done...
#     Solving...   (tInd = 329)
#     Done...
#     Solving...   (tInd = 330)
#     Done...
#     Solving...   (tInd = 331)
#     Done...
#     Solving...   (tInd = 332)
#     Done...
#     Solving...   (tInd = 333)
#     Done...
#     Solving...   (tInd = 334)
#     Done...
#     Solving...   (tInd = 335)
#     Done...
#     Solving...   (tInd = 336)
#     Done...
#     Solving...   (tInd = 337)
#     Done...
#     Solving...   (tInd = 338)
#     Done...
#     Solving...   (tInd = 339)
#     Done...
#     Solving...   (tInd = 340)
#     Done...
#     Solving...   (tInd = 341)
#     Done...
#     Solving...   (tInd = 342)
#     Done...
#     Solving...   (tInd = 343)
#     Done...
#     Solving...   (tInd = 344)
#     Done...
#     Solving...   (tInd = 345)
#     Done...
#     Solving...   (tInd = 346)
#     Done...
#     Solving...   (tInd = 347)
#     Done...
#     Solving...   (tInd = 348)
#     Done...
#     Solving...   (tInd = 349)
#     Done...
#     Solving...   (tInd = 350)
#     Done...
#     Solving...   (tInd = 351)
#     Done...
#     Solving...   (tInd = 352)
#     Done...
#     Solving...   (tInd = 353)
#     Done...
#     Solving...   (tInd = 354)
#     Done...
#     Solving...   (tInd = 355)
#     Done...
#     Solving...   (tInd = 356)
#     Done...
#     Solving...   (tInd = 357)
#     Done...
#     Solving...   (tInd = 358)
#     Done...
#     Solving...   (tInd = 359)
#     Done...
#     Solving...   (tInd = 360)
#     Done...
#     Solving...   (tInd = 361)
#     Done...
#     Solving...   (tInd = 362)
#     Done...
#     Solving...   (tInd = 363)
#     Done...
#     Solving...   (tInd = 364)
#     Done...
#     Solving...   (tInd = 365)
#     Done...
#     Solving...   (tInd = 366)
#     Done...
#     Solving...   (tInd = 367)
#     Done...
#     Solving...   (tInd = 368)
#     Done...
#     Solving...   (tInd = 369)
#     Done...
#     Solving...   (tInd = 370)
#     Done...
#     Solving...   (tInd = 371)
#     Done...
#     Solving...   (tInd = 372)
#     Done...
#     Solving...   (tInd = 373)
#     Done...
#     Solving...   (tInd = 374)
#     Done...
#     Solving...   (tInd = 375)
#     Done...
#     Solving...   (tInd = 376)
#     Done...
#     Solving...   (tInd = 377)
#     Done...
#     Solving...   (tInd = 378)
#     Done...
#     Solving...   (tInd = 379)
#     Done...
#     Solving...   (tInd = 380)
#     Done...
#     Solving...   (tInd = 381)
#     Done...
#     Solving...   (tInd = 382)
#     Done...
#     Solving...   (tInd = 383)
#     Done...
#     Solving...   (tInd = 384)
#     Done...
#     Solving...   (tInd = 385)
#     Done...
#     Solving...   (tInd = 386)
#     Done...
#     Solving...   (tInd = 387)
#     Done...
#     Solving...   (tInd = 388)
#     Done...
#     Solving...   (tInd = 389)
#     Done...
#     Solving...   (tInd = 390)
#     Done...
#     Solving...   (tInd = 391)
#     Done...
#     Solving...   (tInd = 392)
#     Done...
#     Solving...   (tInd = 393)
#     Done...
#     Solving...   (tInd = 394)
#     Done...
#     Solving...   (tInd = 395)
#     Done...
#     Solving...   (tInd = 396)
#     Done...
#     Solving...   (tInd = 397)
#     Done...
#     Solving...   (tInd = 398)
#     Done...
#     Solving...   (tInd = 399)
#     Done...
#     Solving...   (tInd = 400)
#     Done...
#     Solving...   (tInd = 401)
#     Done...
#     Solving...   (tInd = 402)
#     Done...
#     Solving...   (tInd = 403)
#     Done...
#     Solving...   (tInd = 404)
#     Done...
#     Solving...   (tInd = 405)
#     Done...
#     Solving...   (tInd = 406)
#     Done...
# Factoring...   (dt = 3.000000e-05)
# Done
#     Solving...   (tInd = 407)
#     Done...
#     Solving...   (tInd = 408)
#     Done...
#     Solving...   (tInd = 409)
#     Done...
#     Solving...   (tInd = 410)
#     Done...
#     Solving...   (tInd = 411)
#     Done...
#     Solving...   (tInd = 412)
#     Done...
#     Solving...   (tInd = 413)
#     Done...
#     Solving...   (tInd = 414)
#     Done...
#     Solving...   (tInd = 415)
#     Done...
#     Solving...   (tInd = 416)
#     Done...
#     Solving...   (tInd = 417)
#     Done...
#     Solving...   (tInd = 418)
#     Done...
#     Solving...   (tInd = 419)
#     Done...
#     Solving...   (tInd = 420)
#     Done...
#     Solving...   (tInd = 421)
#     Done...
#     Solving...   (tInd = 422)
#     Done...
#     Solving...   (tInd = 423)
#     Done...
#     Solving...   (tInd = 424)
#     Done...
#     Solving...   (tInd = 425)
#     Done...
#     Solving...   (tInd = 426)
#     Done...
#     Solving...   (tInd = 427)
#     Done...
#     Solving...   (tInd = 428)
#     Done...
#     Solving...   (tInd = 429)
#     Done...
#     Solving...   (tInd = 430)
#     Done...
#     Solving...   (tInd = 431)
#     Done...
#     Solving...   (tInd = 432)
#     Done...
#     Solving...   (tInd = 433)
#     Done...
#     Solving...   (tInd = 434)
#     Done...
#     Solving...   (tInd = 435)
#     Done...
#     Solving...   (tInd = 436)
#     Done...
#     Solving...   (tInd = 437)
#     Done...
#     Solving...   (tInd = 438)
#     Done...
#     Solving...   (tInd = 439)
#     Done...
#     Solving...   (tInd = 440)
#     Done...
#     Solving...   (tInd = 441)
#     Done...
#     Solving...   (tInd = 442)
#     Done...
#     Solving...   (tInd = 443)
#     Done...
#     Solving...   (tInd = 444)
#     Done...
#     Solving...   (tInd = 445)
#     Done...
#     Solving...   (tInd = 446)
#     Done...
#     Solving...   (tInd = 447)
#     Done...
#     Solving...   (tInd = 448)
#     Done...
#     Solving...   (tInd = 449)
#     Done...
#     Solving...   (tInd = 450)
#     Done...
#     Solving...   (tInd = 451)
#     Done...
#     Solving...   (tInd = 452)
#     Done...
#     Solving...   (tInd = 453)
#     Done...
#     Solving...   (tInd = 454)
#     Done...
#     Solving...   (tInd = 455)
#     Done...
#     Solving...   (tInd = 456)
#     Done...
#     Solving...   (tInd = 457)
#     Done...
#     Solving...   (tInd = 458)
#     Done...
#     Solving...   (tInd = 459)
#     Done...
#     Solving...   (tInd = 460)
#     Done...
#     Solving...   (tInd = 461)
#     Done...
#     Solving...   (tInd = 462)
#     Done...
#     Solving...   (tInd = 463)
#     Done...
#     Solving...   (tInd = 464)
#     Done...
#     Solving...   (tInd = 465)
#     Done...
#     Solving...   (tInd = 466)
#     Done...
#     Solving...   (tInd = 467)
#     Done...
#     Solving...   (tInd = 468)
#     Done...
#     Solving...   (tInd = 469)
#     Done...
#     Solving...   (tInd = 470)
#     Done...
#     Solving...   (tInd = 471)
#     Done...
#     Solving...   (tInd = 472)
#     Done...
#     Solving...   (tInd = 473)
#     Done...
#     Solving...   (tInd = 474)
#     Done...
#     Solving...   (tInd = 475)
#     Done...
#     Solving...   (tInd = 476)
#     Done...
#     Solving...   (tInd = 477)
#     Done...
#     Solving...   (tInd = 478)
#     Done...
#     Solving...   (tInd = 479)
#     Done...
#     Solving...   (tInd = 480)
#     Done...
#     Solving...   (tInd = 481)
#     Done...
#     Solving...   (tInd = 482)
#     Done...
#     Solving...   (tInd = 483)
#     Done...
#     Solving...   (tInd = 484)
#     Done...
#     Solving...   (tInd = 485)
#     Done...
#     Solving...   (tInd = 486)
#     Done...
#     Solving...   (tInd = 487)
#     Done...
# Factoring...   (dt = 1.000000e-04)
# Done
#     Solving...   (tInd = 488)
#     Done...
#     Solving...   (tInd = 489)
#     Done...
#     Solving...   (tInd = 490)
#     Done...
#     Solving...   (tInd = 491)
#     Done...
#     Solving...   (tInd = 492)
#     Done...
#     Solving...   (tInd = 493)
#     Done...
#     Solving...   (tInd = 494)
#     Done...
#     Solving...   (tInd = 495)
#     Done...
#     Solving...   (tInd = 496)
#     Done...
#     Solving...   (tInd = 497)
#     Done...
#     Solving...   (tInd = 498)
#     Done...
#     Solving...   (tInd = 499)
#     Done...
#     Solving...   (tInd = 500)
#     Done...
#     Solving...   (tInd = 501)
#     Done...
#     Solving...   (tInd = 502)
#     Done...
#     Solving...   (tInd = 503)
#     Done...
#     Solving...   (tInd = 504)
#     Done...
#     Solving...   (tInd = 505)
#     Done...
#     Solving...   (tInd = 506)
#     Done...
#     Solving...   (tInd = 507)
#     Done...
#     Solving...   (tInd = 508)
#     Done...
#     Solving...   (tInd = 509)
#     Done...
#     Solving...   (tInd = 510)
#     Done...
#     Solving...   (tInd = 511)
#     Done...
#     Solving...   (tInd = 512)
#     Done...
#     Solving...   (tInd = 513)
#     Done...
#     Solving...   (tInd = 514)
#     Done...
#     Solving...   (tInd = 515)
#     Done...
#     Solving...   (tInd = 516)
#     Done...
#     Solving...   (tInd = 517)
#     Done...
#     Solving...   (tInd = 518)
#     Done...
#     Solving...   (tInd = 519)
#     Done...
#     Solving...   (tInd = 520)
#     Done...
#     Solving...   (tInd = 521)
#     Done...
#     Solving...   (tInd = 522)
#     Done...
#     Solving...   (tInd = 523)
#     Done...
#     Solving...   (tInd = 524)
#     Done...
#     Solving...   (tInd = 525)
#     Done...
#     Solving...   (tInd = 526)
#     Done...
#     Solving...   (tInd = 527)
#     Done...
#     Solving...   (tInd = 528)
#     Done...
#     Solving...   (tInd = 529)
#     Done...
#     Solving...   (tInd = 530)
#     Done...
#     Solving...   (tInd = 531)
#     Done...
#     Solving...   (tInd = 532)
#     Done...
#     Solving...   (tInd = 533)
#     Done...
#     Solving...   (tInd = 534)
#     Done...
#     Solving...   (tInd = 535)
#     Done...
#     Solving...   (tInd = 536)
#     Done...
#     Solving...   (tInd = 537)
#     Done...
#     Solving...   (tInd = 538)
#     Done...
#     Solving...   (tInd = 539)
#     Done...
#     Solving...   (tInd = 540)
#     Done...
#     Solving...   (tInd = 541)
#     Done...
#     Solving...   (tInd = 542)
#     Done...
#     Solving...   (tInd = 543)
#     Done...
#     Solving...   (tInd = 544)
#     Done...
#     Solving...   (tInd = 545)
#     Done...
#     Solving...   (tInd = 546)
#     Done...
#     Solving...   (tInd = 547)
#     Done...
#     Solving...   (tInd = 548)
#     Done...
#     Solving...   (tInd = 549)
#     Done...
#     Solving...   (tInd = 550)
#     Done...
#     Solving...   (tInd = 551)
#     Done...
#     Solving...   (tInd = 552)
#     Done...
#     Solving...   (tInd = 553)
#     Done...
#     Solving...   (tInd = 554)
#     Done...
#     Solving...   (tInd = 555)
#     Done...
#     Solving...   (tInd = 556)
#     Done...
#     Solving...   (tInd = 557)
#     Done...
#     Solving...   (tInd = 558)
#     Done...
#     Solving...   (tInd = 559)
#     Done...
#     Solving...   (tInd = 560)
#     Done...
#     Solving...   (tInd = 561)
#     Done...
#     Solving...   (tInd = 562)
#     Done...
#     Solving...   (tInd = 563)
#     Done...
#     Solving...   (tInd = 564)
#     Done...
#     Solving...   (tInd = 565)
#     Done...
#     Solving...   (tInd = 566)
#     Done...
#     Solving...   (tInd = 567)
#     Done...
#     Solving...   (tInd = 568)
#     Done...
# Factoring...   (dt = 3.000000e-04)
# Done
#     Solving...   (tInd = 569)
#     Done...
#     Solving...   (tInd = 570)
#     Done...
#     Solving...   (tInd = 571)
#     Done...
#     Solving...   (tInd = 572)
#     Done...
#     Solving...   (tInd = 573)
#     Done...
#     Solving...   (tInd = 574)
#     Done...
#     Solving...   (tInd = 575)
#     Done...
#     Solving...   (tInd = 576)
#     Done...
#     Solving...   (tInd = 577)
#     Done...
#     Solving...   (tInd = 578)
#     Done...
#     Solving...   (tInd = 579)
#     Done...
#     Solving...   (tInd = 580)
#     Done...
#     Solving...   (tInd = 581)
#     Done...
#     Solving...   (tInd = 582)
#     Done...
#     Solving...   (tInd = 583)
#     Done...
#     Solving...   (tInd = 584)
#     Done...
#     Solving...   (tInd = 585)
#     Done...
#     Solving...   (tInd = 586)
#     Done...
#     Solving...   (tInd = 587)
#     Done...
#     Solving...   (tInd = 588)
#     Done...
#     Solving...   (tInd = 589)
#     Done...
#     Solving...   (tInd = 590)
#     Done...
#     Solving...   (tInd = 591)
#     Done...
#     Solving...   (tInd = 592)
#     Done...
#     Solving...   (tInd = 593)
#     Done...
#     Solving...   (tInd = 594)
#     Done...
#     Solving...   (tInd = 595)
#     Done...
#     Solving...   (tInd = 596)
#     Done...
#     Solving...   (tInd = 597)
#     Done...
#     Solving...   (tInd = 598)
#     Done...
#     Solving...   (tInd = 599)
#     Done...
#     Solving...   (tInd = 600)
#     Done...
#     Solving...   (tInd = 601)
#     Done...
#     Solving...   (tInd = 602)
#     Done...
#     Solving...   (tInd = 603)
#     Done...
#     Solving...   (tInd = 604)
#     Done...
#     Solving...   (tInd = 605)
#     Done...
#     Solving...   (tInd = 606)
#     Done...
#     Solving...   (tInd = 607)
#     Done...
#     Solving...   (tInd = 608)
#     Done...
#     Solving...   (tInd = 609)
#     Done...
#     Solving...   (tInd = 610)
#     Done...
#     Solving...   (tInd = 611)
#     Done...
#     Solving...   (tInd = 612)
#     Done...
#     Solving...   (tInd = 613)
#     Done...
#     Solving...   (tInd = 614)
#     Done...
#     Solving...   (tInd = 615)
#     Done...
#     Solving...   (tInd = 616)
#     Done...
#     Solving...   (tInd = 617)
#     Done...
#     Solving...   (tInd = 618)
#     Done...
#     Solving...   (tInd = 619)
#     Done...
#     Solving...   (tInd = 620)
#     Done...
#     Solving...   (tInd = 621)
#     Done...
#     Solving...   (tInd = 622)
#     Done...
#     Solving...   (tInd = 623)
#     Done...
#     Solving...   (tInd = 624)
#     Done...
#     Solving...   (tInd = 625)
#     Done...
#     Solving...   (tInd = 626)
#     Done...
#     Solving...   (tInd = 627)
#     Done...
#     Solving...   (tInd = 628)
#     Done...
#     Solving...   (tInd = 629)
#     Done...
#     Solving...   (tInd = 630)
#     Done...
#     Solving...   (tInd = 631)
#     Done...
#     Solving...   (tInd = 632)
#     Done...
#     Solving...   (tInd = 633)
#     Done...
#     Solving...   (tInd = 634)
#     Done...
#     Solving...   (tInd = 635)
#     Done...
#     Solving...   (tInd = 636)
#     Done...
#     Solving...   (tInd = 637)
#     Done...
#     Solving...   (tInd = 638)
#     Done...
#     Solving...   (tInd = 639)
#     Done...
#     Solving...   (tInd = 640)
#     Done...
#     Solving...   (tInd = 641)
#     Done...
#     Solving...   (tInd = 642)
#     Done...
#     Solving...   (tInd = 643)
#     Done...
#     Solving...   (tInd = 644)
#     Done...
#     Solving...   (tInd = 645)
#     Done...
#     Solving...   (tInd = 646)
#     Done...
#     Solving...   (tInd = 647)
#     Done...
#     Solving...   (tInd = 648)
#     Done...
#     Solving...   (tInd = 649)
#     Done...
# Factoring...   (dt = 1.000000e-03)
# Done
#     Solving...   (tInd = 650)
#     Done...
#     Solving...   (tInd = 651)
#     Done...
#     Solving...   (tInd = 652)
#     Done...
#     Solving...   (tInd = 653)
#     Done...
#     Solving...   (tInd = 654)
#     Done...
#     Solving...   (tInd = 655)
#     Done...
#     Solving...   (tInd = 656)
#     Done...
#     Solving...   (tInd = 657)
#     Done...
#     Solving...   (tInd = 658)
#     Done...
#     Solving...   (tInd = 659)
#     Done...
#     Solving...   (tInd = 660)
#     Done...
#     Solving...   (tInd = 661)
#     Done...
#     Solving...   (tInd = 662)
#     Done...
#     Solving...   (tInd = 663)
#     Done...
#     Solving...   (tInd = 664)
#     Done...
#     Solving...   (tInd = 665)
#     Done...
#     Solving...   (tInd = 666)
#     Done...
#     Solving...   (tInd = 667)
#     Done...
#     Solving...   (tInd = 668)
#     Done...
#     Solving...   (tInd = 669)
#     Done...
#     Solving...   (tInd = 670)
#     Done...
#     Solving...   (tInd = 671)
#     Done...
#     Solving...   (tInd = 672)
#     Done...
#     Solving...   (tInd = 673)
#     Done...
#     Solving...   (tInd = 674)
#     Done...
#     Solving...   (tInd = 675)
#     Done...
#     Solving...   (tInd = 676)
#     Done...
#     Solving...   (tInd = 677)
#     Done...
#     Solving...   (tInd = 678)
#     Done...
#     Solving...   (tInd = 679)
#     Done...
#     Solving...   (tInd = 680)
#     Done...
#     Solving...   (tInd = 681)
#     Done...
#     Solving...   (tInd = 682)
#     Done...
#     Solving...   (tInd = 683)
#     Done...
#     Solving...   (tInd = 684)
#     Done...
#     Solving...   (tInd = 685)
#     Done...
#     Solving...   (tInd = 686)
#     Done...
#     Solving...   (tInd = 687)
#     Done...
#     Solving...   (tInd = 688)
#     Done...
#     Solving...   (tInd = 689)
#     Done...
#     Solving...   (tInd = 690)
#     Done...
#     Solving...   (tInd = 691)
#     Done...
#     Solving...   (tInd = 692)
#     Done...
#     Solving...   (tInd = 693)
#     Done...
#     Solving...   (tInd = 694)
#     Done...
#     Solving...   (tInd = 695)
#     Done...
#     Solving...   (tInd = 696)
#     Done...
#     Solving...   (tInd = 697)
#     Done...
#     Solving...   (tInd = 698)
#     Done...
#     Solving...   (tInd = 699)
#     Done...
#     Solving...   (tInd = 700)
#     Done...
#     Solving...   (tInd = 701)
#     Done...
#     Solving...   (tInd = 702)
#     Done...
#     Solving...   (tInd = 703)
#     Done...
#     Solving...   (tInd = 704)
#     Done...
#     Solving...   (tInd = 705)
#     Done...
#     Solving...   (tInd = 706)
#     Done...
#     Solving...   (tInd = 707)
#     Done...
#     Solving...   (tInd = 708)
#     Done...
#     Solving...   (tInd = 709)
#     Done...
#     Solving...   (tInd = 710)
#     Done...
#     Solving...   (tInd = 711)
#     Done...
#     Solving...   (tInd = 712)
#     Done...
#     Solving...   (tInd = 713)
#     Done...
#     Solving...   (tInd = 714)
#     Done...
#     Solving...   (tInd = 715)
#     Done...
#     Solving...   (tInd = 716)
#     Done...
#     Solving...   (tInd = 717)
#     Done...
#     Solving...   (tInd = 718)
#     Done...
#     Solving...   (tInd = 719)
#     Done...
#     Solving...   (tInd = 720)
#     Done...
#     Solving...   (tInd = 721)
#     Done...
#     Solving...   (tInd = 722)
#     Done...
#     Solving...   (tInd = 723)
#     Done...
#     Solving...   (tInd = 724)
#     Done...
#     Solving...   (tInd = 725)
#     Done...
#     Solving...   (tInd = 726)
#     Done...
#     Solving...   (tInd = 727)
#     Done...
#     Solving...   (tInd = 728)
#     Done...
#     Solving...   (tInd = 729)
#     Done...
#     Solving...   (tInd = 730)
#     Done...
# Factoring...   (dt = 3.000000e-03)
# Done
#     Solving...   (tInd = 731)
#     Done...
#     Solving...   (tInd = 732)
#     Done...
#     Solving...   (tInd = 733)
#     Done...
#     Solving...   (tInd = 734)
#     Done...
#     Solving...   (tInd = 735)
#     Done...
#     Solving...   (tInd = 736)
#     Done...
#     Solving...   (tInd = 737)
#     Done...
#     Solving...   (tInd = 738)
#     Done...
#     Solving...   (tInd = 739)
#     Done...
#     Solving...   (tInd = 740)
#     Done...
#     Solving...   (tInd = 741)
#     Done...
#     Solving...   (tInd = 742)
#     Done...
#     Solving...   (tInd = 743)
#     Done...
#     Solving...   (tInd = 744)
#     Done...
#     Solving...   (tInd = 745)
#     Done...
#     Solving...   (tInd = 746)
#     Done...
#     Solving...   (tInd = 747)
#     Done...
#     Solving...   (tInd = 748)
#     Done...
#     Solving...   (tInd = 749)
#     Done...
#     Solving...   (tInd = 750)
#     Done...
#     Solving...   (tInd = 751)
#     Done...
#     Solving...   (tInd = 752)
#     Done...
#     Solving...   (tInd = 753)
#     Done...
#     Solving...   (tInd = 754)
#     Done...
#     Solving...   (tInd = 755)
#     Done...
#     Solving...   (tInd = 756)
#     Done...
#     Solving...   (tInd = 757)
#     Done...
#     Solving...   (tInd = 758)
#     Done...
#     Solving...   (tInd = 759)
#     Done...
#     Solving...   (tInd = 760)
#     Done...
#     Solving...   (tInd = 761)
#     Done...
#     Solving...   (tInd = 762)
#     Done...
#     Solving...   (tInd = 763)
#     Done...
#     Solving...   (tInd = 764)
#     Done...
#     Solving...   (tInd = 765)
#     Done...
#     Solving...   (tInd = 766)
#     Done...
#     Solving...   (tInd = 767)
#     Done...
#     Solving...   (tInd = 768)
#     Done...
#     Solving...   (tInd = 769)
#     Done...
#     Solving...   (tInd = 770)
#     Done...
#     Solving...   (tInd = 771)
#     Done...
#     Solving...   (tInd = 772)
#     Done...
#     Solving...   (tInd = 773)
#     Done...
#     Solving...   (tInd = 774)
#     Done...
#     Solving...   (tInd = 775)
#     Done...
#     Solving...   (tInd = 776)
#     Done...
#     Solving...   (tInd = 777)
#     Done...
#     Solving...   (tInd = 778)
#     Done...
#     Solving...   (tInd = 779)
#     Done...
#     Solving...   (tInd = 780)
#     Done...
#     Solving...   (tInd = 781)
#     Done...
#     Solving...   (tInd = 782)
#     Done...
#     Solving...   (tInd = 783)
#     Done...
#     Solving...   (tInd = 784)
#     Done...
#     Solving...   (tInd = 785)
#     Done...
#     Solving...   (tInd = 786)
#     Done...
#     Solving...   (tInd = 787)
#     Done...
#     Solving...   (tInd = 788)
#     Done...
#     Solving...   (tInd = 789)
#     Done...
#     Solving...   (tInd = 790)
#     Done...
#     Solving...   (tInd = 791)
#     Done...
# **************************************************
# Done calculating fields(m)
# **************************************************

# %%
# Source: 100 m x-directed diplole at the origin,
# 50 m above seafloor, src [x1, x2, y1, y2, z1, z2]

src = [-60, -50, 0, 0, -1.56, -1.56]

# Receiver: x-directed dipole at 2 km on the
# seafloor, rec = [x, y, z, azimuth, dip]
rec = [50, 0, -1.56, 0, 0]

# Times to compute, 0.1 - 10 s, 301 steps
times = np.logspace(np.log10(1e-6), np.log10(1e-2), 300)

inp = {
    "src": src.copy(),
    "rec": rec.copy(),
    "depth": [0, -9.5, -49.5, -49.55, -90.5],
    # "res": [1e4,res_sea, res_bg],
    "res": [1e8, 10, 100, 1e-6, 100, 300],
    "freqtime": times,
    "signal": -1,  # Switch-off
    "srcpts": 100,  # 5 points for finite length approx
    "strength": 1.02,  # Account for source length
    "verb": 1,
}

inp2 = {
    "src": src.copy(),
    "rec": rec.copy(),
    "depth": [0.06, -9.94, -50, -50.05, -94.96],
    # "res": [1e4,res_sea, res_bg],
    "res": [1e8, 10, 100, 1e-6, 100, 300],
    "freqtime": times,
    "signal": -1,  # Switch-off
    "srcpts": 100,  # 5 points for finite length approx
    "strength": 1,  # Account for source length
    "verb": 1,
}

epm_bg = empymod.bipole(**inp2)

fig= plt.subplots(figsize=(6, 6))

plt.rcParams["font.family"] = "Times New Roman"

ax1 = plt.subplot(111)
# ax1.loglog(times, np.abs(epm_bg), "k--")
ax1.loglog(times, np.abs(epm_bg), "C0-")

# %%
dobs = np.load("./data2/3D_solution_changdepth.npy").reshape((3,300))
# dana = np.load("./data/analytic_solution.npy")

fig, ax = plt.subplots(figsize=(6, 6))
plt.rcParams["font.family"] = "Times New Roman"

ax.loglog(times, np.abs(epm_bg), "k-")
ax.loglog(times, np.abs(dobs[0]), "C0--")

ax.set_xlabel("Times / s")
ax.set_ylabel("E$_x$ / (V/m))")
ax.tick_params(axis='both', which='major', labelsize=14)
ax.legend(["Analytic solution", "Numerical solution"], loc = 1, fontsize = 12)
plt.savefig("./HighConductivityLayer_depth0.05m_1e6.png", dpi=350, bbox_inches='tight')
